# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# URL for GET requests to retrieve city data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# List for holding reponse information
lon = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lat = []
date = []
country = []
cloudiness = []


# Loop through the list of cities and request for data on each
print("Beginning Data Retrieval")
print("-------------------------------------")
count = 0
set = 1
for index, city in enumerate(cities):
    count = count + 1
    # To avoid api call rate limits, get city weather data in sets of 50 cities,
    # with 5 seconds sleep time, and then continue
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
print("-------------------------------------")
print("Data Retrieval Complete")
print("-------------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | yantal
# Processing Record 6 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 1 | flin flon
# Processing Record 8 of Set 1 | chabahar
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | lagoa
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | mehamn
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | vagur
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | evensk
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | itupiranga
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | ponta delgada
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | pauini
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | kenai
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | cap malheureux
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | pacific grove
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | zhigalovo
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | takoradi
# Processing Record 40 of Set 1 | havoysund
# Processing Record 41 of Set 1 | oranjestad
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | grand gaube
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | byron bay
# Processing Record 46 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | ballina
# Processing Record 49 of Set 1 | belgrade
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | mamallapuram
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | dingle
# Processing Record 6 of Set 2 | alberton
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | bay roberts
# Processing Record 10 of Set 2 | sakakah
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 13 of Set 2 | aswan
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | aklavik
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | kenora
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | breves
# Processing Record 22 of Set 2 | labuan
# Processing Record 23 of Set 2 | huanta
# Processing Record 24 of Set 2 | fort nelson
# Processing Record 25 of Set 2 | erzin
# Processing Record 26 of Set 2 | alofi
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | touros
# Processing Record 29 of Set 2 | green valley
# Processing Record 30 of Set 2 | isiro
# Processing Record 31 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | kudahuvadhoo
# Processing Record 34 of Set 2 | lokosovo
# Processing Record 35 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | leningradskiy
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | matay
# Processing Record 41 of Set 2 | matamoros
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | pyshchug
# Processing Record 44 of Set 2 | hobyo
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | punalur
# Processing Record 5 of Set 3 | hasaki
# Processing Record 6 of Set 3 | bull savanna
# Processing Record 7 of Set 3 | norman wells
# Processing Record 8 of Set 3 | luderitz
# Processing Record 9 of Set 3 | maningrida
# Processing Record 10 of Set 3 | tagusao
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | puerto penasco
# Processing Record 13 of Set 3 | sao joao da barra
# Processing Record 14 of Set 3 | fukue
# Processing Record 15 of Set 3 | aksarka
# Processing Record 16 of Set 3 | biak
# Processing Record 17 of Set 3 | albany
# Processing Record 18 of Set 3 | yongan
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | urumqi
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | salalah
# Processing Record 23 of Set 3 | phan thiet
# Processing Record 24 of Set 3 | college
# Processing Record 25 of Set 3 | suhbaatar
# Processing Record 26 of Set 3 | yulara
# Processing Record 27 of Set 3 | alausi
# Processing Record 28 of Set 3 | palmerston north
# Processing Record 29 of Set 3 | zholymbet
# Processing Record 30 of Set 3 | irtyshskiy
# Processing Record 31 of Set 3 | bafia
# Processing Record 32 of Set 3 | hambantota
# Processing Record 33 of Set 3 | kaohsiung
# Processing Record 34 of Set 3 | balakovo
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 3 | portland
# Processing Record 38 of Set 3 | eyl
# Processing Record 39 of Set 3 | osorno
# Processing Record 40 of Set 3 | thompson
# Processing Record 41 of Set 3 | nome
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | swan hill
# Processing Record 45 of Set 3 | namibe
# Processing Record 46 of Set 3 | sete
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | sovetskiy
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | gerash
# Processing Record 1 of Set 4 | bogovarovo
# Processing Record 2 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 4 | oxapampa
# Processing Record 4 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | lima
# Processing Record 7 of Set 4 | el escorial
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | kidal
# Processing Record 10 of Set 4 | druzhba
# Processing Record 11 of Set 4 | japura
# Processing Record 12 of Set 4 | aykhal
# Processing Record 13 of Set 4 | saint george
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | port macquarie
# Processing Record 16 of Set 4 | caravelas
# Processing Record 17 of Set 4 | cuenca
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | la ronge
# Processing Record 22 of Set 4 | hirara
# Processing Record 23 of Set 4 | querecotillo
# Processing Record 24 of Set 4 | ndioum
# Processing Record 25 of Set 4 | lithakia
# Processing Record 26 of Set 4 | vung tau
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | kavaratti
# Processing Record 29 of Set 4 | darhan
# Processing Record 30 of Set 4 | butaritari
# Processing Record 31 of Set 4 | ola
# Processing Record 32 of Set 4 | pasighat
# Processing Record 33 of Set 4 | benguela
# Processing Record 34 of Set 4 | nishihara
# Processing Record 35 of Set 4 | panjab
# Processing Record 36 of Set 4 | kawalu
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | sibu
# Processing Record 39 of Set 4 | poronaysk
# Processing Record 40 of Set 4 | nanortalik
# Processing Record 41 of Set 4 | tuatapere
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | banjar
# Processing Record 46 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 4 | cabra
# Processing Record 48 of Set 4 | nkhotakota
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | castro
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | isla mujeres
# Processing Record 3 of Set 5 | pandan
# Processing Record 4 of Set 5 | tourlaville
# Processing Record 5 of Set 5 | mildura
# Processing Record 6 of Set 5 | sable-sur-sarthe
# Processing Record 7 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 5 | robe
# Processing Record 9 of Set 5 | banda aceh
# Processing Record 10 of Set 5 | westport
# Processing Record 11 of Set 5 | kisaran
# Processing Record 12 of Set 5 | samarai
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | kedrovyy
# Processing Record 15 of Set 5 | juneau
# Processing Record 16 of Set 5 | clyde river
# Processing Record 17 of Set 5 | tiznit
# Processing Record 18 of Set 5 | ye
# City not found. Skipping...
# Processing Record 19 of Set 5 | pyshma
# Processing Record 20 of Set 5 | kamloops
# Processing Record 21 of Set 5 | ulladulla
# Processing Record 22 of Set 5 | puerto barrios
# Processing Record 23 of Set 5 | kununurra
# Processing Record 24 of Set 5 | bandarbeyla
# Processing Record 25 of Set 5 | bonavista
# Processing Record 26 of Set 5 | tonantins
# Processing Record 27 of Set 5 | nchelenge
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | kaitangata
# Processing Record 30 of Set 5 | emba
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | ixtapa
# Processing Record 34 of Set 5 | fare
# Processing Record 35 of Set 5 | mosquera
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | pedernales
# Processing Record 38 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 39 of Set 5 | port jervis
# Processing Record 40 of Set 5 | cherskiy
# Processing Record 41 of Set 5 | west plains
# Processing Record 42 of Set 5 | linjiang
# Processing Record 43 of Set 5 | thiers
# Processing Record 44 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 45 of Set 5 | ontario
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | san patricio
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | walvis bay
# Processing Record 1 of Set 6 | mecca
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | providencia
# Processing Record 4 of Set 6 | gimli
# Processing Record 5 of Set 6 | bardiyah
# Processing Record 6 of Set 6 | asau
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | new norfolk
# Processing Record 9 of Set 6 | ahipara
# Processing Record 10 of Set 6 | grindavik
# Processing Record 11 of Set 6 | karimganj
# Processing Record 12 of Set 6 | moctezuma
# Processing Record 13 of Set 6 | visnes
# Processing Record 14 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 15 of Set 6 | vanavara
# Processing Record 16 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 17 of Set 6 | kemijarvi
# Processing Record 18 of Set 6 | sassandra
# Processing Record 19 of Set 6 | chuy
# Processing Record 20 of Set 6 | luanda
# Processing Record 21 of Set 6 | pishin
# Processing Record 22 of Set 6 | belokurikha
# Processing Record 23 of Set 6 | fulacunda
# City not found. Skipping...
# Processing Record 24 of Set 6 | garissa
# Processing Record 25 of Set 6 | lira
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | isoka
# Processing Record 28 of Set 6 | araouane
# Processing Record 29 of Set 6 | rawson
# Processing Record 30 of Set 6 | port-gentil
# Processing Record 31 of Set 6 | los llanos de aridane
# Processing Record 32 of Set 6 | cairns
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | akdepe
# Processing Record 35 of Set 6 | mali
# Processing Record 36 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 6 | florianopolis
# Processing Record 38 of Set 6 | coahuayana
# Processing Record 39 of Set 6 | zhezkazgan
# Processing Record 40 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 6 | alamosa
# Processing Record 42 of Set 6 | barguzin
# Processing Record 43 of Set 6 | high level
# Processing Record 44 of Set 6 | harper
# Processing Record 45 of Set 6 | lagos
# Processing Record 46 of Set 6 | bubaque
# Processing Record 47 of Set 6 | khandyga
# Processing Record 48 of Set 6 | gamba
# Processing Record 49 of Set 6 | pevek
# Processing Record 50 of Set 6 | antalaha
# Processing Record 1 of Set 7 | white rock
# Processing Record 2 of Set 7 | marsaxlokk
# Processing Record 3 of Set 7 | san policarpo
# Processing Record 4 of Set 7 | omsukchan
# Processing Record 5 of Set 7 | clonakilty
# Processing Record 6 of Set 7 | namatanai
# Processing Record 7 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 7 | itaituba
# Processing Record 9 of Set 7 | boa vista
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | necochea
# Processing Record 12 of Set 7 | murgab
# Processing Record 13 of Set 7 | trairi
# Processing Record 14 of Set 7 | tiarei
# Processing Record 15 of Set 7 | mizan teferi
# Processing Record 16 of Set 7 | lufilufi
# Processing Record 17 of Set 7 | atasu
# Processing Record 18 of Set 7 | allapalli
# Processing Record 19 of Set 7 | chislaz
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | flinders
# Processing Record 23 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 7 | lavrentiya
# Processing Record 25 of Set 7 | port-cartier
# Processing Record 26 of Set 7 | kangaatsiaq
# Processing Record 27 of Set 7 | meulaboh
# Processing Record 28 of Set 7 | maldonado
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | hong gai
# Processing Record 31 of Set 7 | south sioux city
# Processing Record 32 of Set 7 | panguna
# Processing Record 33 of Set 7 | avdon
# Processing Record 34 of Set 7 | moose factory
# Processing Record 35 of Set 7 | north myrtle beach
# Processing Record 36 of Set 7 | haimen
# Processing Record 37 of Set 7 | lethem
# Processing Record 38 of Set 7 | geraldton
# Processing Record 39 of Set 7 | georgetown
# Processing Record 40 of Set 7 | kapit
# Processing Record 41 of Set 7 | cayenne
# Processing Record 42 of Set 7 | ypsonas
# Processing Record 43 of Set 7 | krasnorechenskiy
# Processing Record 44 of Set 7 | saskylakh
# Processing Record 45 of Set 7 | tabou
# Processing Record 46 of Set 7 | dinan
# Processing Record 47 of Set 7 | paamiut
# Processing Record 48 of Set 7 | nuuk
# Processing Record 49 of Set 7 | ono
# Processing Record 50 of Set 7 | jaicos
# Processing Record 1 of Set 8 | houston
# Processing Record 2 of Set 8 | carnarvon
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | manokwari
# Processing Record 5 of Set 8 | airai
# Processing Record 6 of Set 8 | alexandria
# Processing Record 7 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 8 | tromso
# Processing Record 9 of Set 8 | port alberni
# Processing Record 10 of Set 8 | lodwar
# Processing Record 11 of Set 8 | margate
# Processing Record 12 of Set 8 | bathsheba
# Processing Record 13 of Set 8 | daokou
# Processing Record 14 of Set 8 | mayskiy
# Processing Record 15 of Set 8 | bowen
# Processing Record 16 of Set 8 | san cristobal
# Processing Record 17 of Set 8 | san quintin
# Processing Record 18 of Set 8 | sungai padi
# Processing Record 19 of Set 8 | mapiripan
# Processing Record 20 of Set 8 | vila velha
# Processing Record 21 of Set 8 | mbanza-ngungu
# Processing Record 22 of Set 8 | egvekinot
# Processing Record 23 of Set 8 | tilichiki
# Processing Record 24 of Set 8 | puerto baquerizo moreno
# Processing Record 25 of Set 8 | ndjole
# Processing Record 26 of Set 8 | hofn
# Processing Record 27 of Set 8 | victoria point
# Processing Record 28 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 8 | havelock
# Processing Record 30 of Set 8 | usinsk
# Processing Record 31 of Set 8 | noumea
# Processing Record 32 of Set 8 | pakxe
# Processing Record 33 of Set 8 | deputatskiy
# Processing Record 34 of Set 8 | hay river
# Processing Record 35 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 36 of Set 8 | pakxan
# Processing Record 37 of Set 8 | tottori
# Processing Record 38 of Set 8 | celarevo
# Processing Record 39 of Set 8 | hasilpur
# Processing Record 40 of Set 8 | doha
# Processing Record 41 of Set 8 | ningbo
# Processing Record 42 of Set 8 | ho
# City not found. Skipping...
# Processing Record 43 of Set 8 | ascension
# Processing Record 44 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 8 | sioux lookout
# Processing Record 46 of Set 8 | pemba
# Processing Record 47 of Set 8 | trang
# Processing Record 48 of Set 8 | sokolo
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | wajima
# Processing Record 1 of Set 9 | sola
# Processing Record 2 of Set 9 | los chiles
# Processing Record 3 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 9 | kosh-agach
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | leshan
# Processing Record 7 of Set 9 | la macarena
# Processing Record 8 of Set 9 | dalby
# Processing Record 9 of Set 9 | ustka
# Processing Record 10 of Set 9 | xining
# Processing Record 11 of Set 9 | pangnirtung
# Processing Record 12 of Set 9 | altamira
# Processing Record 13 of Set 9 | shimoda
# Processing Record 14 of Set 9 | marsh harbour
# Processing Record 15 of Set 9 | mastic
# Processing Record 16 of Set 9 | eenhana
# Processing Record 17 of Set 9 | manicore
# Processing Record 18 of Set 9 | port blair
# Processing Record 19 of Set 9 | peterhead
# Processing Record 20 of Set 9 | saiha
# Processing Record 21 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 9 | puerto lumbreras
# Processing Record 23 of Set 9 | tokuyama
# Processing Record 24 of Set 9 | atar
# Processing Record 25 of Set 9 | tripoli
# Processing Record 26 of Set 9 | shieli
# Processing Record 27 of Set 9 | caiaponia
# Processing Record 28 of Set 9 | passage west
# Processing Record 29 of Set 9 | ukiah
# Processing Record 30 of Set 9 | wilmington
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | liverpool
# Processing Record 33 of Set 9 | nanfeng
# Processing Record 34 of Set 9 | shitanjing
# Processing Record 35 of Set 9 | baryatino
# Processing Record 36 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 37 of Set 9 | kloulklubed
# Processing Record 38 of Set 9 | maceio
# Processing Record 39 of Set 9 | bairiki
# Processing Record 40 of Set 9 | williams lake
# Processing Record 41 of Set 9 | huilong
# Processing Record 42 of Set 9 | ankang
# Processing Record 43 of Set 9 | alice springs
# Processing Record 44 of Set 9 | cam ranh
# Processing Record 45 of Set 9 | venice
# Processing Record 46 of Set 9 | ayagoz
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | mananjary
# Processing Record 49 of Set 9 | bodden town
# Processing Record 50 of Set 9 | north bend
# Processing Record 1 of Set 10 | odesskoye
# Processing Record 2 of Set 10 | cubuk
# Processing Record 3 of Set 10 | kysyl-syr
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | banikoara
# Processing Record 6 of Set 10 | san lorenzo
# Processing Record 7 of Set 10 | bundaberg
# Processing Record 8 of Set 10 | jos
# Processing Record 9 of Set 10 | beloha
# Processing Record 10 of Set 10 | tigzirt
# Processing Record 11 of Set 10 | mitsamiouli
# Processing Record 12 of Set 10 | salta
# Processing Record 13 of Set 10 | vestmannaeyjar
# Processing Record 14 of Set 10 | hohhot
# Processing Record 15 of Set 10 | ketchikan
# Processing Record 16 of Set 10 | delijan
# Processing Record 17 of Set 10 | turukhansk
# Processing Record 18 of Set 10 | madimba
# Processing Record 19 of Set 10 | teeli
# Processing Record 20 of Set 10 | priargunsk
# Processing Record 21 of Set 10 | anaco
# Processing Record 22 of Set 10 | mondlo
# Processing Record 23 of Set 10 | lyaskelya
# Processing Record 24 of Set 10 | laguna
# Processing Record 25 of Set 10 | lhokseumawe
# Processing Record 26 of Set 10 | vanimo
# Processing Record 27 of Set 10 | cremlingen
# Processing Record 28 of Set 10 | nuqui
# Processing Record 29 of Set 10 | lasa
# Processing Record 30 of Set 10 | vikevag
# Processing Record 31 of Set 10 | champerico
# Processing Record 32 of Set 10 | ossora
# Processing Record 33 of Set 10 | sheridan
# Processing Record 34 of Set 10 | nueva loja
# Processing Record 35 of Set 10 | chumikan
# Processing Record 36 of Set 10 | arrecife
# Processing Record 37 of Set 10 | outjo
# Processing Record 38 of Set 10 | muros
# Processing Record 39 of Set 10 | launceston
# Processing Record 40 of Set 10 | east london
# Processing Record 41 of Set 10 | sidi ali
# Processing Record 42 of Set 10 | salihli
# Processing Record 43 of Set 10 | mirik
# Processing Record 44 of Set 10 | ravar
# Processing Record 45 of Set 10 | taybad
# Processing Record 46 of Set 10 | nosy varika
# Processing Record 47 of Set 10 | pangai
# Processing Record 48 of Set 10 | itarema
# Processing Record 49 of Set 10 | hauterive
# Processing Record 50 of Set 10 | oranjemund
# Processing Record 1 of Set 11 | sao felix do xingu
# Processing Record 2 of Set 11 | rock sound
# Processing Record 3 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 11 | kingston
# Processing Record 5 of Set 11 | gaoual
# Processing Record 6 of Set 11 | isangel
# Processing Record 7 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 11 | vao
# Processing Record 9 of Set 11 | goderich
# Processing Record 10 of Set 11 | kamaishi
# Processing Record 11 of Set 11 | dongsheng
# Processing Record 12 of Set 11 | talcahuano
# Processing Record 13 of Set 11 | joao pinheiro
# Processing Record 14 of Set 11 | kongoussi
# Processing Record 15 of Set 11 | srinagar
# Processing Record 16 of Set 11 | barabinsk
# Processing Record 17 of Set 11 | vardo
# Processing Record 18 of Set 11 | coquimbo
# Processing Record 19 of Set 11 | kuusamo
# Processing Record 20 of Set 11 | brownwood
# Processing Record 21 of Set 11 | macherla
# Processing Record 22 of Set 11 | broome
# Processing Record 23 of Set 11 | tasiilaq
# Processing Record 24 of Set 11 | chara
# Processing Record 25 of Set 11 | kamenskiy
# Processing Record 26 of Set 11 | suntar
# Processing Record 27 of Set 11 | mtambile
# Processing Record 28 of Set 11 | puerto escondido
# Processing Record 29 of Set 11 | okha
# Processing Record 30 of Set 11 | xingyi
# Processing Record 31 of Set 11 | henties bay
# Processing Record 32 of Set 11 | mahibadhoo
# Processing Record 33 of Set 11 | barreirinhas
# Processing Record 34 of Set 11 | traverse city
# Processing Record 35 of Set 11 | olafsvik
# Processing Record 36 of Set 11 | kautokeino
# Processing Record 37 of Set 11 | taoudenni
# Processing Record 38 of Set 11 | ashoknagar
# Processing Record 39 of Set 11 | thinadhoo
# Processing Record 40 of Set 11 | qasigiannguit
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | payson
# Processing Record 43 of Set 11 | shache
# Processing Record 44 of Set 11 | hanyang
# Processing Record 45 of Set 11 | agua dulce
# Processing Record 46 of Set 11 | lixourion
# Processing Record 47 of Set 11 | afgoye
# City not found. Skipping...
# Processing Record 48 of Set 11 | yokadouma
# Processing Record 49 of Set 11 | kyabe
# Processing Record 50 of Set 11 | tukrah
# Processing Record 1 of Set 12 | beringovskiy
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | russell
# Processing Record 4 of Set 12 | cuamba
# Processing Record 5 of Set 12 | raudeberg
# Processing Record 6 of Set 12 | viedma
# Processing Record 7 of Set 12 | cukai
# Processing Record 8 of Set 12 | negele
# City not found. Skipping...
# Processing Record 9 of Set 12 | leshukonskoye
# Processing Record 10 of Set 12 | catamarca
# Processing Record 11 of Set 12 | mantua
# Processing Record 12 of Set 12 | natal
# Processing Record 13 of Set 12 | bambanglipuro
# Processing Record 14 of Set 12 | itanhem
# Processing Record 15 of Set 12 | almeirim
# Processing Record 16 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | mandalgovi
# Processing Record 19 of Set 12 | burnie
# Processing Record 20 of Set 12 | bilma
# Processing Record 21 of Set 12 | brae
# Processing Record 22 of Set 12 | acarau
# Processing Record 23 of Set 12 | sibolga
# Processing Record 24 of Set 12 | beidao
# Processing Record 25 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 12 | chifeng
# Processing Record 27 of Set 12 | puerto lempira
# Processing Record 28 of Set 12 | bogorodskoye
# Processing Record 29 of Set 12 | popondetta
# Processing Record 30 of Set 12 | le port
# Processing Record 31 of Set 12 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 32 of Set 12 | poum
# Processing Record 33 of Set 12 | timaru
# Processing Record 34 of Set 12 | kachiry
# Processing Record 35 of Set 12 | rucheng
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | nantucket
# Processing Record 38 of Set 12 | kutum
# Processing Record 39 of Set 12 | shu
# Processing Record 40 of Set 12 | usvyaty
# Processing Record 41 of Set 12 | dubna
# Processing Record 42 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 12 | anito
# Processing Record 44 of Set 12 | palana
# Processing Record 45 of Set 12 | cockburn town
# Processing Record 46 of Set 12 | sudzha
# Processing Record 47 of Set 12 | mount gambier
# Processing Record 48 of Set 12 | moultrie
# Processing Record 49 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 50 of Set 12 | lagoa vermelha
# Processing Record 1 of Set 13 | nisia floresta
# Processing Record 2 of Set 13 | camargo
# Processing Record 3 of Set 13 | sojat
# Processing Record 4 of Set 13 | tongren
# Processing Record 5 of Set 13 | aracati
# Processing Record 6 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 13 | canton
# Processing Record 8 of Set 13 | barbar
# City not found. Skipping...
# -------------------------------------
# Data Retrieval Complete
# -------------------------------------

# %%
# Check if we got response for all cities
len(lat)
len(temp_max)
# Out:
# 608

# %%
city_data_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# Drop any cities that were skipped because they could not return any response from OpenWeatherMap API.
city_data_df = cities_df.dropna(how="any")

city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  rikitea -23.1203 -134.9692     79.52      71.0         2.0        8.84
# 1  hualmay -11.0964  -77.6139     75.27      76.0        98.0        6.55
# 2  qaanaaq  77.4840  -69.3632    -10.37      62.0        11.0        7.58
# 3  ushuaia -54.8000  -68.3000     42.46      81.0        75.0       26.46
# 4   yantal  56.8471  105.2542     26.80      95.0       100.0       14.79
#
#   Country          Date
# 0      PF  1.679278e+09
# 1      PE  1.679278e+09
# 2      GL  1.679278e+09
# 3      AR  1.679278e+09
# 4      RU  1.679278e+09

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        rikitea -23.1203 -134.9692     79.52      71.0         2.0
# 1        hualmay -11.0964  -77.6139     75.27      76.0        98.0
# 2        qaanaaq  77.4840  -69.3632    -10.37      62.0        11.0
# 3        ushuaia -54.8000  -68.3000     42.46      81.0        75.0
# 4         yantal  56.8471  105.2542     26.80      95.0       100.0
#
#          Wind Speed Country          Date
# City_ID
# 0              8.84      PF  1.679278e+09
# 1              6.55      PE  1.679278e+09
# 2              7.58      GL  1.679278e+09
# 3             26.46      AR  1.679278e+09
# 4             14.79      RU  1.679278e+09

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
date_now = datetime.date(datetime.now())

# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

# Incorporate the other graph properties
# YOUR CODE HERE

plt.scatter(x_values,y_values, marker = "o", facecolor = "steelblue", edgecolor="black")

plt.xlabel('Latitude')
plt.ylabel('Max Temprature (F)')
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

plt.scatter(x_values,y_values, marker = "o", facecolor = "steelblue", edgecolor="black")

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.grid()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

plt.scatter(x_values,y_values, marker = "o", facecolor = "steelblue", edgecolor="black")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.grid()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

plt.scatter(x_values,y_values, marker = "o", facecolor = "steelblue", edgecolor="black")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.grid()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Generate plots     
    fig1, ax1 = plt.subplots(figsize=(12,8))
    plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
    plt.plot(x_values,regress_values,"r-")
    date_now = datetime.date(datetime.now())
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} {date_now}",fontsize = 15)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    if ylim is not None:
        plt.ylim(0, ylim)
    plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_weather_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_weather_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2          qaanaaq  77.4840  -69.3632    -10.37      62.0        11.0
# 4           yantal  56.8471  105.2542     26.80      95.0       100.0
# 6        flin flon  54.7682 -101.8650     -0.87      99.0       100.0
# 7         chabahar  25.2919   60.6430     72.59      63.0         0.0
# 8           kodiak  57.7900 -152.4072     36.91      52.0        40.0
#
#          Wind Speed Country          Date
# City_ID
# 2              7.58      GL  1.679278e+09
# 4             14.79      RU  1.679278e+09
# 6              3.96      CA  1.679278e+09
# 7              0.87      IR  1.679278e+09
# 8              5.75      US  1.679278e+09

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_weather_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         rikitea -23.1203 -134.9692     79.52      71.0         2.0
# 1         hualmay -11.0964  -77.6139     75.27      76.0        98.0
# 3         ushuaia -54.8000  -68.3000     42.46      81.0        75.0
# 9          hobart -42.8794  147.3294     59.25      52.0        40.0
# 15       cidreira -30.1811  -50.2056     74.14      80.0        31.0
#
#          Wind Speed Country          Date
# City_ID
# 0              8.84      PF  1.679278e+09
# 1              6.55      PE  1.679278e+09
# 3             26.46      AR  1.679278e+09
# 9             13.80      AU  1.679278e+09
# 15             9.26      BR  1.679278e+09

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Southern Hemisphere
x_values = northern_hemi_weather_df["Lat"]
y_values = northern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (10, 10))

plt.show()
# Out:
# The r-squared is: 0.7910631672370981
# The correlation between both factors is -0.89

# %%
x_values = southern_hemi_weather_df["Lat"]
y_values = southern_hemi_weather_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 75))

plt.show()
# Out:
# The r-squared is: 0.23008993957457596
# The correlation between both factors is 0.48

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The correlation between latitude and maximum temperature is strong for both the hemispheres. It is higher for northern hemisphere (0.89), indicating that as we move away from the equator, the maximum temperature keeps dropping in a more linear manner. Meanwhile, the r-value for southern hemisphere is 0.48, indicating a increase in temperature when getting closer to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(50,50))

plt.show()
# Out:
# The r-squared is: 0.07329996000367464
# The correlation between both factors is 0.27

# %%
# Create a scatter plot for latitude vs humditiy (southern hemisphere)
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Humidity']
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(50, 50), 100)

plt.show()
# Out:
# The r-squared is: 0.09647230433655002
# The correlation between both factors is 0.31

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The r-value on Northern Hemiphere is 0.27 shows the further away from equator, the more humdity it gets.
#
# The r-value on Southern Hemisphere is 0.31 shows the closer to the equator, the more humdity it gets.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

plt.show()
# Out:
# The r-squared is: 0.045189433202946425
# The correlation between both factors is 0.21

# %%
# Southern Hemisphere
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

plt.show()
# Out:
# The r-squared is: 0.09488294312696932
# The correlation between both factors is 0.31

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The r-value on Northern Hemiphere is 0.21 shows the further away from equator, the more cloudy it is.
#
# The r-value on Southern Hemisphere is 0.31 shows the closer to the equator, the more cloudy it is.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_weather_df['Lat']
y_values = northern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))

plt.show()
# Out:
# The r-squared is: 0.046754705366325776
# The correlation between both factors is 0.22

# %%
# Southern Hemisphere
x_values = southern_hemi_weather_df['Lat']
y_values = southern_hemi_weather_df['Wind Speed']
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)

plt.show()
# Out:
# The r-squared is: 0.18614425047997168
# The correlation between both factors is -0.43

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The r-value on Northern Hemiphere is 0.22 shows the further away from equator, the more windy it is.
#
# The r-value on Southern Hemisphere is (0.43) shows the closer to the equator, the less windy it is.
